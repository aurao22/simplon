# %% [markdown]
# ## Classification

# %% [markdown]
# #### Classification binaire

# %% [markdown]
# Un  problèmes de classification, qui consistent par exemple à classer un email en tant que
# 'spam' ou 'non spam'.
# Dans cet exemple notre variable target 𝒚 pouvant prendre 2 valeurs seulement, par exemple 0 ou 1
# - si 𝑦 = 0, alors l’email n’est pas un spam
# - si 𝑦 = 1, alors l’email est un spam
#
# On dit également que l’on a 2 **classes**, c’est une classification binaire.

# %% [markdown]
# ## Exercice

# %% [markdown]
# Avec make_classification on génére des données aléatoire

# %%
import numpy as np
import matplotlib.pyplot as plt 
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# %%
# Génération de données aléatoires: 100 exemples, 2 classes, 2 features x0 et x1
np.random.seed(1)
X, y = make_classification(n_samples=100,n_features=2, n_redundant=0, n_informative=1,
 n_clusters_per_class=1)

# %%
# Visualisation des données
plt.figure(num=None, figsize=(8, 6))
plt.scatter(X[:,0], X[:, 1], marker = 'o', c=y, edgecolors='k')
plt.xlabel('X0')
plt.ylabel('X1')
X.shape
# Out:
# (100, 2)

# %% [markdown]
# **Vous allez créer un model qui permet de classifier ce dataset à l'aide d'une régression logistique**

# %%
#X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=5)

# %%
softmax_reg = LogisticRegression(solver="liblinear", C=10, random_state=42)
softmax_reg.fit(X, y)
# Out:
# LogisticRegression(C=10, random_state=42, solver='liblinear')

# %%
#xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
# np.arange(y_min, y_max, h))
#np.c_[xx.ravel(), yy.ravel()]
print(xx.shape)
print(yy.shape)
# Out:
# (294, 349)
# (294, 349)

# %%
# Visualisation des données
h = .002
colors = "bry"
x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
 np.arange(y_min, y_max, h))
np.c_[xx.ravel(), yy.ravel()]
Z = softmax_reg.predict(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)
cs = plt.contourf(xx, yy, Z, cmap=plt.cm.Paired)
plt.axis('tight')

for i, color in zip(softmax_reg.classes_, colors):
 idx = np.where(y == i)
 plt.scatter(X[idx, 0], X[idx, 1], c=color, cmap=plt.cm.Paired, edgecolor='black', s
=20)

# %% [markdown]
# Paul

# %%
### Détermination de la taille du graphique (ici 120% du min/max)
MULT_GRAPH_SIZE = 1.2
x_min, x_max = X[:, 0].min() * MULT_GRAPH_SIZE, X[:, 0].max() * MULT_GRAPH_SIZE
y_min, y_max = X[:, 1].min() * MULT_GRAPH_SIZE, X[:, 1].max() * MULT_GRAPH_SIZE

### Construction d'une grille pour le graph
GRID_PRECISION = 0.01
xx, yy = np.meshgrid(  
    np.arange(x_min, x_max, GRID_PRECISION), 
    np.arange(y_min, y_max, GRID_PRECISION))

### Détermination de la ligne de séparation
Z = model_logi.predict(np.c_[xx.ravel(), yy.ravel()]).reshape(xx.shape)

### Application de la grille + ligne
plt.contourf(xx, yy, Z)

### Plot
plt.scatter(X[:, 0], X[:, 1], c=Y, s=40, edgecolors="grey", alpha=0.9)
plt.title('Binary Logistic Regression')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_23420/1122697723.py in <module>
#      11
#      12 ### Détermination de la ligne de séparation
# ---> 13 Z = model_logi.predict(np.c_[xx.ravel(), yy.ravel()]).reshape(xx.shape)
#      14
#      15 ### Application de la grille + ligne
#
# NameError: name 'model_logi' is not defined
