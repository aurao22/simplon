# %% [markdown]
# ## Des algorithmes d'apprentissage supervisé les plus importants
# - Linear Regression
# - k-Nearest Neighbors
# - Logistic Regression
# - Support Vector Machines (SVMs)
# - Decision Trees and Random Forests
# - Neural networks

# %% [markdown]
# https://scikit-learn.org/stable/index.html

# %%
import matplotlib.pyplot as plt
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression

# %%
import numpy as np
import matplotlib.pyplot as plt 
import numpy.random as rnd
import sklearn

# %%
np.random.seed(42)
m = 100
X = 6 * np.random.rand(m, 1) - 3
y = 0.5 * X**2 + X + 2 + np.random.randn(m, 1)

# %%
import seaborn as sns

# %%
plt.scatter(X,y)

# %%
poly = PolynomialFeatures(degree=2)

# %%
polyFeat=poly.fit(X)

# %%
X_poly=polyFeat.transform(X)

# %%
lr = LinearRegression()

# %%
lr = lr.fit(X_poly, y)
Y_pred = lr.predict(X_poly)

# %%
plt.plot(X, y, marker='o', ls='', label='data')
#plt.plot(X, y, ls='--', label='Fonction réelle')
plt.plot(X, Y_pred, marker='^',alpha=.5, label='prediction polynomiale')
plt.legend()

ax = plt.gca()
ax.set(xlabel='x data', ylabel='y data')
# Out:
# [Text(0.5, 0, 'x data'), Text(0, 0.5, 'y data')]

# %%
print("coeff:"+str(lr.coef_[0][1::]))
print("intercept :"+str(lr.intercept_[0]))
# Out:
# coeff:[0.93366893 0.56456263]
# intercept :1.781345812029145

# %%
plt.scatter(X, Y_pred, marker='*',linestyle='solid')
plt.scatter(X, y, marker='^')
plt.show()

# %% [markdown]
# # affichons la prédiction et les data

# %%
x = np.linspace(-3,3, 40)
z = lr.coef_[0][2]*x**2+lr.coef_[0][1]*x+lr.intercept_[0]
plt.plot(x, z)
plt.scatter(X, y, marker='^')
#plt.scatter(X, Y_pred, marker='*')
