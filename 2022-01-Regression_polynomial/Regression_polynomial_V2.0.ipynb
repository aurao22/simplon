# %% [markdown]
# ## Des algorithmes d'apprentissage supervisé les plus importants
# - Linear Regression
# - k-Nearest Neighbors
# - Logistic Regression
# - Support Vector Machines (SVMs)
# - Decision Trees and Random Forests
# - Neural networks

# %% [markdown]
# https://scikit-learn.org/stable/index.html

# %%
import numpy as np
import matplotlib.pyplot as plt 
import numpy.random as rnd
import operator
from sklearn.preprocessing import PolynomialFeatures
from sklearn.preprocessing import PolynomialFeatures, SplineTransformer
from sklearn.metrics import mean_squared_error
from sklearn.pipeline import make_pipeline
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.linear_model import Ridge

# %%
np.random.seed(42)
m = 100
X = 6 * np.random.rand(m, 1) - 3
y = 0.5 * X**2 + X + 2 + np.random.randn(m, 1)

# %%
plt.figure()
plt.scatter(X,y)
plt.title("Visualisation de l'allure des données")
plt.show()

# %% [markdown]
# une parabole est un polynome de degré 2

# %%
degree = 2
poly_features = PolynomialFeatures(degree, include_bias=False)
X_poly = poly_features.fit_transform(X)
X[0]
# Out:
# array([-0.75275929])

# %%
lin_reg = LinearRegression()
lin_reg.fit(X_poly,y)
lin_reg.intercept_, lin_reg.coef_
# Out:
# (array([1.78134581]), array([[0.93366893, 0.56456263]]))

# %%
poly_t = lin_reg.predict(X_poly)

# %%
poly_t
# Out:
# array([[1.39842532],
#        [8.43499142],
#        [4.17485459],
#        [2.53185804],
#        [2.25918793],
#        [2.25939008],
#        [3.27484983],
#        [6.55784665],
#        [2.55559366],
#        [3.82689353],
#        [3.76696465],
#        [8.90169299],
#        [5.88989222],
#        [1.85167304],
#        [2.05645803],
#        [2.0449286 ],
#        [1.46355599],
#        [1.93248803],
#        [1.49423227],
#        [1.49764679],
#        [2.66222542],
#        [2.40322072],
#        [1.49502331],
#        [1.3956771 ],
#        [1.57447195],
#        [5.03178213],
#        [1.93207743],
#        [1.86520541],
#        [2.47263182],
#        [3.42140098],
#        [2.61888173],
#        [2.14190381],
#        [3.18970382],
#        [8.39130997],
#        [8.79638932],
#        [5.44200996],
#        [1.46268375],
#        [2.81734047],
#        [3.50326369],
#        [1.51887514],
#        [2.56742224],
#        [1.75479958],
#        [3.57916148],
#        [7.47955479],
#        [1.61263738],
#        [3.22863242],
#        [1.44709879],
#        [1.90195223],
#        [2.08736191],
#        [2.03443439],
#        [8.89366107],
#        [4.8611505 ],
#        [8.16924409],
#        [7.16149437],
#        [2.52457873],
#        [7.7619586 ],
#        [2.91775243],
#        [1.95673578],
#        [3.43712908],
#        [1.42292667],
#        [1.4095878 ],
#        [1.56301774],
#        [5.81934649],
#        [1.39592177],
#        [1.52949263],
#        [2.05758006],
#        [2.39031461],
#        [5.33032964],
#        [3.07680827],
#        [9.32693832],
#        [4.81284186],
#        [1.93842511],
#        [3.98072454],
#        [5.57115179],
#        [3.80983753],
#        [4.13013805],
#        [4.79661914],
#        [3.08272947],
#        [1.39560336],
#        [2.62841658],
#        [6.49508918],
#        [2.78104162],
#        [1.41521603],
#        [3.20778451],
#        [1.44860474],
#        [1.42314733],
#        [4.13907708],
#        [2.93652136],
#        [6.99780775],
#        [1.64138398],
#        [2.5914008 ],
#        [3.90015774],
#        [4.62449623],
#        [2.20093695],
#        [4.79157972],
#        [1.74737103],
#        [1.91919863],
#        [1.48213813],
#        [3.70030835],
#        [2.70958481]])

# %%
X
# Out:
# array([[-0.75275929],
#        [ 2.70428584],
#        [ 1.39196365],
#        [ 0.59195091],
#        [-2.06388816],
#        [-2.06403288],
#        [-2.65149833],
#        [ 2.19705687],
#        [ 0.60669007],
#        [ 1.24843547],
#        [-2.87649303],
#        [ 2.81945911],
#        [ 1.99465584],
#        [-1.72596534],
#        [-1.9090502 ],
#        [-1.89957294],
#        [-1.17454654],
#        [ 0.14853859],
#        [-0.40832989],
#        [-1.25262516],
#        [ 0.67111737],
#        [-2.16303684],
#        [-1.24713211],
#        [-0.80182894],
#        [-0.26358009],
#        [ 1.71105577],
#        [-1.80195731],
#        [ 0.08540663],
#        [ 0.55448741],
#        [-2.72129752],
#        [ 0.64526911],
#        [-1.97685526],
#        [-2.60969044],
#        [ 2.69331322],
#        [ 2.7937922 ],
#        [ 1.85038409],
#        [-1.17231738],
#        [-2.41396732],
#        [ 1.10539816],
#        [-0.35908504],
#        [-2.26777059],
#        [-0.02893854],
#        [-2.79366887],
#        [ 2.45592241],
#        [-1.44732011],
#        [ 0.97513371],
#        [-1.12973354],
#        [ 0.12040813],
#        [ 0.28026168],
#        [-1.89087327],
#        [ 2.81750777],
#        [ 1.65079694],
#        [ 2.63699365],
#        [ 2.3689641 ],
#        [ 0.58739987],
#        [ 2.53124541],
#        [-2.46904499],
#        [-1.82410283],
#        [-2.72863627],
#        [-1.04801802],
#        [-0.66793626],
#        [-1.37190581],
#        [ 1.97242505],
#        [-0.85948004],
#        [-1.31439294],
#        [ 0.2561765 ],
#        [-2.15445465],
#        [ 1.81318188],
#        [-2.55269614],
#        [ 2.92132162],
#        [ 1.63346862],
#        [-1.80770591],
#        [-2.9668673 ],
#        [ 1.89276857],
#        [ 1.24114406],
#        [ 1.37404301],
#        [ 1.62762208],
#        [-2.55573209],
#        [-0.84920563],
#        [-2.30478564],
#        [ 2.17862056],
#        [ 0.73978876],
#        [-1.01461185],
#        [-2.6186499 ],
#        [-1.13410607],
#        [-1.04890007],
#        [ 1.37763707],
#        [ 0.82534483],
#        [ 2.32327646],
#        [-0.16671045],
#        [-2.28243452],
#        [ 1.27946872],
#        [ 1.56471029],
#        [ 0.36766319],
#        [ 1.62580308],
#        [-0.03722642],
#        [ 0.13639698],
#        [-0.43475389],
#        [-2.84748524],
#        [-2.35265144]])

# %%
plt.figure()
plt.scatter(X,y)
plt.plot(X,poly_t,"r")
plt.title("Polynomial regression")
plt.show()

# %% [markdown]
# Version Marwa

# %%
# Nouvelles données générées
X_new = np.linspace(-3,3,100).reshape(100, 1)
X_new_poly = poly_features.transform(X_new)
y_new = lin_reg.predict(X_new_poly)

fig, ax = plt.subplots()
ax.plot(X, y, 'b.')
ax.plot(X_new, y_new, 'r-', linewidth=2, label="Predictions")
plt.xlabel("$x_1$", fontsize=18)
plt.ylabel("$y$", rotation=0, fontsize=18)
plt.legend(fontsize=14)
plt.axis([-3, 3, 0, 10])
plt.show()

# %% [markdown]
# Version Paul

# %%
# Nouvelles données générées
steps = 100
x_new = np.linspace(min(X), max(X), steps).reshape(steps, 1)
X_new_poly = poly_features.transform(X_new)
y_new = lin_reg.predict(X_new_poly)

fig, ax = plt.subplots()
ax.plot(X, y, 'b.')
ax.plot(X_new, y_new, 'r-', linewidth=2, label="Predictions")
plt.xlabel("$x_1$", fontsize=18)
plt.ylabel("$y$", rotation=0, fontsize=18)
plt.legend(fontsize=14)
plt.axis([-3, 3, 0, 10])
plt.show()

# %% [markdown]
# Version en séparant les données en 2 data set
# Dataset trop petit pour le découper

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.8)

X_poly = poly_features.transform(X_train)

lin_reg = LinearRegression()
lin_reg.fit(X_poly,y_train)

X_new_poly = poly_features.transform(X_test)
y_new = lin_reg.predict(X_new_poly)

# %%
X_new = np.linspace(-3,3,100).reshape(100, 1)
X_new_poly2 = poly_features.transform(X_new)
y_new2 = lin_reg.predict(X_new_poly2)

# %%
fig, ax = plt.subplots()
ax.scatter(X_train, y_train)
#ax.plot()
# ax.plot(X, y, 'b.')
#ax.plot(x_p, y_test_2, 'g.', label="Valeurs attendues")
# ax.plot(X_test, y_new, 'r-', label="Predictions")
ax.plot(X_new, y_new2, 'g-', label="Predictions2")
plt.xlabel("$x_1$", fontsize=18)
plt.ylabel("$y$", rotation=0, fontsize=18)
plt.legend()
# plt.axis([-3, 3, 0, 10])
# fig.set_size_inches(15, 7, forward=True)
plt.show()

# %%
print(type(X_new_poly), len(X_new_poly), X_new_poly.shape)
X_new_poly
# Out:
# <class 'numpy.ndarray'> 20 (20, 2)
# array([[ 1.99465584,  3.97865194],
#        [ 0.59195091,  0.35040587],
#        [-1.89957294,  3.60837736],
#        [-2.26777059,  5.14278345],
#        [ 1.27946872,  1.63704021],
#        [-2.41396732,  5.8272382 ],
#        [ 1.56471029,  2.4483183 ],
#        [-2.15445465,  4.64167484],
#        [-2.65149833,  7.03044338],
#        [ 1.65079694,  2.72513054],
#        [-1.24713211,  1.5553385 ],
#        [-1.97685526,  3.90795671],
#        [ 1.89276857,  3.58257286],
#        [ 2.19705687,  4.82705891],
#        [-1.72596534,  2.97895634],
#        [ 0.13639698,  0.01860414],
#        [-1.9090502 ,  3.64447265],
#        [-1.89087327,  3.57540171],
#        [ 0.36766319,  0.13517622],
#        [ 2.92132162,  8.53412001]])

# %%
print(type(y_new), len(y_new), y_new.shape)
# Out:
# <class 'numpy.ndarray'> 20 (20, 1)

# %%
np_arrr = np.concatenate((X_new_poly, y_new, y_test), axis=1)
np_arrr
# Out:
# array([[ 1.99465584,  3.97865194,  5.88989222,  5.45422161],
#        [ 0.59195091,  0.35040587,  2.53185804,  0.77958493],
#        [-1.89957294,  3.60837736,  2.0449286 ,  2.87326073],
#        [-2.26777059,  5.14278345,  2.56742224,  2.26890937],
#        [ 1.27946872,  1.63704021,  3.90015774,  5.99478181],
#        [-2.41396732,  5.8272382 ,  2.81734047,  4.9628939 ],
#        [ 1.56471029,  2.4483183 ,  4.62449623,  4.54348132],
#        [-2.15445465,  4.64167484,  2.39031461,  0.55889954],
#        [-2.65149833,  7.03044338,  3.27484983,  4.34161741],
#        [ 1.65079694,  2.72513054,  4.8611505 ,  4.44706448],
#        [-1.24713211,  1.5553385 ,  1.49502331,  1.5356506 ],
#        [-1.97685526,  3.90795671,  2.14190381,  2.15170091],
#        [ 1.89276857,  3.58257286,  5.57115179,  5.98103968],
#        [ 2.19705687,  4.82705891,  6.55784665,  6.09231611],
#        [-1.72596534,  2.97895634,  1.85167304,  2.27678027],
#        [ 0.13639698,  0.01860414,  1.91919863,  2.06859733],
#        [-1.9090502 ,  3.64447265,  2.05645803,  2.01026368],
#        [-1.89087327,  3.57540171,  2.03443439,  4.08728321],
#        [ 0.36766319,  0.13517622,  2.20093695,  1.68151513],
#        [ 2.92132162,  8.53412001,  9.32693832,  9.97020449]])

# %%
# sort the values of x before line plot
# sort_axis = operator.itemgetter(0)
# sorted_zip = sorted(np_arrr, key=sort_axis)
np.sort(np_arrr, axis=0)
x_p = np_arrr[:,0:2]
y_poly_pred_P = np_arrr[:,2]
y_test_2 = np_arrr[:,3]

# %%
x_p
# Out:
# array([[ 1.99465584,  3.97865194],
#        [ 0.59195091,  0.35040587],
#        [-1.89957294,  3.60837736],
#        [-2.26777059,  5.14278345],
#        [ 1.27946872,  1.63704021],
#        [-2.41396732,  5.8272382 ],
#        [ 1.56471029,  2.4483183 ],
#        [-2.15445465,  4.64167484],
#        [-2.65149833,  7.03044338],
#        [ 1.65079694,  2.72513054],
#        [-1.24713211,  1.5553385 ],
#        [-1.97685526,  3.90795671],
#        [ 1.89276857,  3.58257286],
#        [ 2.19705687,  4.82705891],
#        [-1.72596534,  2.97895634],
#        [ 0.13639698,  0.01860414],
#        [-1.9090502 ,  3.64447265],
#        [-1.89087327,  3.57540171],
#        [ 0.36766319,  0.13517622],
#        [ 2.92132162,  8.53412001]])

# %%
y_poly_pred_P
# Out:
# array([5.88989222, 2.53185804, 2.0449286 , 2.56742224, 3.90015774,
#        2.81734047, 4.62449623, 2.39031461, 3.27484983, 4.8611505 ,
#        1.49502331, 2.14190381, 5.57115179, 6.55784665, 1.85167304,
#        1.91919863, 2.05645803, 2.03443439, 2.20093695, 9.32693832])

# %%
y_test_2
# Out:
# array([5.45422161, 0.77958493, 2.87326073, 2.26890937, 5.99478181,
#        4.9628939 , 4.54348132, 0.55889954, 4.34161741, 4.44706448,
#        1.5356506 , 2.15170091, 5.98103968, 6.09231611, 2.27678027,
#        2.06859733, 2.01026368, 4.08728321, 1.68151513, 9.97020449])

# %%
fig, ax = plt.subplots()
ax.plot(X, y, 'b.')
ax.plot(x_p, y_test_2, 'g.', label="Valeurs attendues")
ax.plot(x_p, y_poly_pred_P, 'r.', label="Predictions")
plt.xlabel("$x_1$", fontsize=18)
plt.ylabel("$y$", rotation=0, fontsize=18)
plt.legend()
plt.axis([-3, 3, 0, 10])
fig.set_size_inches(15, 7, forward=True)
plt.show()

# %%
polyreg=make_pipeline(poly_features,LinearRegression())

# %%
polyreg.fit(X,y)

# %%
plt.figure()
plt.scatter(X,y)
plt.plot(X,poly_t,color="red")
plt.title("Polynomial regression")
plt.show()

# %%
degree=2
polyreg=make_pipeline(PolynomialFeatures(degree),LinearRegression())
polyreg.fit(X,y)
# Out:
# Pipeline(steps=[('polynomialfeatures', PolynomialFeatures()),
#                 ('linearregression', LinearRegression())])

# %%
# sort the values of x before line plot
sort_axis = operator.itemgetter(0)
sorted_zip = sorted(zip(X,y_poly_pred), key=sort_axis)
x_p, y_poly_pred_P = zip(*sorted_zip)
plt.plot(x_p, y_poly_pred_P, color='g')

# %%
plt.figure()
plt.scatter(X,y)
plt.plot(X,polyreg.predict(X),color="red")
plt.title("Polynomial regression with degree "+str(degree))
plt.show()

# %%
coefs = np.polyfit(X.flatten(), y.flatten(), degree)
plt.figure()
plt.plot(X, np.polyval(coefs, X), color="red")
plt.title("Polyfit degree "+str(degree))
plt.scatter(X,y)
plt.show()

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.8)

# %%
# plot function
lw = 2
fig, ax = plt.subplots()
ax.set_prop_cycle(
    color=["black", "teal", "yellowgreen", "gold", "darkorange", "tomato"]
)
ax.scatter(X_test, y_test, label="Tests truth", color="red")

# plot training points
ax.scatter(X_train, y_train, label="training points", color="blue")

# polynomial features
for degree in range(2, 7):
    model = make_pipeline(PolynomialFeatures(degree), Ridge(alpha=1e-3))
    model.fit(X_train, y_train)
    y_plot = model.predict(X_test)
    ax.plot(X_test, y_plot, label=f"degree {degree}")

# B-spline with 4 + 3 - 1 = 6 basis functions
model = make_pipeline(SplineTransformer(n_knots=4, degree=3), Ridge(alpha=1e-3))
model.fit(X_train, y_train)

y_plot = model.predict(X_test)
ax.plot(X_test, y_plot, label="B-spline", color="green")
ax.legend()
fig.set_size_inches(15, 7, forward=True)
plt.show()

# %%
polynomial_features= PolynomialFeatures(degree=2)
x_poly = polynomial_features.fit_transform(X)
 
model = LinearRegression()
model.fit(x_poly, y)
y_poly_pred = model.predict(x_poly)
 
rmse = np.sqrt(mean_squared_error(y,y_poly_pred))
#r2 = r2_score(y,y_poly_pred)
print(rmse)
#print(r2)

plt.scatter(X, y, s=10)
# sort the values of x before line plot
sort_axis = operator.itemgetter(0)
sorted_zip = sorted(zip(X,y_poly_pred), key=sort_axis)
x_p, y_poly_pred_P = zip(*sorted_zip)
plt.plot(x_p, y_poly_pred_P, color='g')
plt.show()
# Out:
# 0.8815858814376717

# %%
fig, ax = plt.subplots()

ax.scatter(X, y, s=10)

for degree in range(2, 40, 1):
    polynomial_features= PolynomialFeatures(degree=degree)
    x_poly = polynomial_features.fit_transform(X)
    
    model = LinearRegression()
    model.fit(x_poly, y)
    y_poly_pred = model.predict(x_poly)
    
    rmse = np.sqrt(mean_squared_error(y,y_poly_pred))
    #r2 = r2_score(y,y_poly_pred)
    # print(rmse)
    #print(r2)

    # sort the values of x before line plot
    sort_axis = operator.itemgetter(0)
    sorted_zip = sorted(zip(X,y_poly_pred), key=sort_axis)
    x_p, y_poly_pred_P = zip(*sorted_zip)
    ax.plot(x_p, y_poly_pred_P, label=f"degree {degree} score:{round(rmse,3)}")
ax.legend()
fig.set_size_inches(15, 7, forward=True)
plt.show()

# %%
fig, ax = plt.subplots()

ax.scatter(X, y, s=10)

for degree in range(2, 10, 1):
    polynomial_features= PolynomialFeatures(degree=degree)
    x_poly = polynomial_features.fit_transform(X)
    
    X_train, X_test, y_train, y_test = train_test_split(x_poly, y, train_size=0.8)

    model = LinearRegression()
    model.fit(X_train, y_train)
    score = model.score(X_test, y_test)
    y_poly_pred = model.predict(X_test)
    
    # rmse = np.sqrt(mean_squared_error(y_test,y_poly_pred))

    # sort the values of x before line plot
    sort_axis = operator.itemgetter(0)
    sorted_zip = sorted(zip(X_test,y_poly_pred), key=sort_axis)
    x_p, y_poly_pred_P = zip(*sorted_zip)
    ax.plot(x_p, y_poly_pred_P, label=f"degree {degree} score:{round(rmse,3)}")
ax.legend()
fig.set_size_inches(15, 7, forward=True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3708/1023674952.py in <module>
#      17     # sort the values of x before line plot
#      18     sort_axis = operator.itemgetter(0)
# ---> 19     sorted_zip = sorted(zip(X_test,y_poly_pred), key=sort_axis)
#      20     x_p, y_poly_pred_P = zip(*sorted_zip)
#      21     ax.plot(x_p, y_poly_pred_P, label=f"degree {degree} score:{round(rmse,3)}")
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
